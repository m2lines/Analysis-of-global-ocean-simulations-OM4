# %%
import sys
sys.path.append('../')
# %load_ext autoreload
# %autoreload 3

import xarray as xr
import matplotlib.pyplot as plt
from helpers.computational_tools import *


from helpers.collection_of_experiments import CollectionOfExperiments
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ds = CollectionOfExperiments.init_folder('/scratch/pp2681/mom6/OM4_SIS2')

# %%
ds += CollectionOfExperiments.init_folder('/scratch/db194/OM4_jun_2025')
ds += CollectionOfExperiments.init_folder('/scratch/db194/OM4_jun_2025', additional_subfolder='')

# %%
ds.exps
# Out:
# ['unparameterized-0.09',
#  'unparameterized',
#  'ZB20-Reynolds',
#  'ANN-FGR-2',
#  'ZB20-Klower',
#  'ANN-5x5-Klower',
#  'ANN-3x3-32-32',
#  'ZB20-Smooth-1.0',
#  'vert-diff',
#  'JHAH15',
#  'ANN-Taper',
#  'ANN-strain',
#  'unparameterized-OM5',
#  'ZB20-Smooth-2.5',
#  'ANN-3x3-EXP2',
#  'ANN-redline',
#  'ANN-greenline',
#  'GM',
#  'ANN-default-plus-dEdt',
#  'SSMh',
#  'ANN-1x1',
#  'SSMh-cumsum',
#  'DMM-R',
#  'unparameterized-0.03',
#  'ANN-SGS',
#  'test_my_ANN_long',
#  'test_my_ANN',
#  'test_my_ANN_long_new',
#  'test_my',
#  'test_my_ANN_long_2',
#  'test_pavel',
#  'test_my_ANN_long-output']

# %%
ds.plot_series(['unparameterized', 'ANN-greenline', 'test_my_ANN_long', 'test_my_ANN_long_2'])

# %%
ds.plot_temp(['unparameterized', 'ANN-greenline', 'test_my_ANN_long', 'test_my_ANN_long_2'], plot_type='response')

# %%
ds.plot_temp(['unparameterized', 'ANN-greenline', 'test_my_ANN_long', 'test_my_ANN_long_2'], plot_type='response', zl=11)

# %%
ds.plot_temp(['unparameterized', 'ANN-greenline', 'test_my_ANN_long', 'test_my_ANN_long_2'], plot_type='response', projection='3D', select=select_NA_large)

# %%
ds.plot_MLD_summer(['unparameterized', 'ANN-greenline', 'test_my_ANN_long', 'test_my_ANN_long_2'], plot_type='response', projection='2D')

# %%
ds.plot_MLD_winter(['unparameterized', 'ANN-greenline', 'test_my_ANN_long', 'test_my_ANN_long_2'], plot_type='response', projection='2D')

# %%
ds.plot_ssh_std(['unparameterized', 'ANN-greenline', 'test_my_ANN_long', 'test_my_ANN_long_2'], plot_type='response', projection='3D', select=select_globe)

# %%
ds.plot_KE_spectrum(['unparameterized', 'ANN-greenline', 'test_my_ANN_long', 'obs'])

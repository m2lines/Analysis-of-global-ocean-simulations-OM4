# %%
import sys
sys.path.append('../')
# %load_ext autoreload
# %autoreload 3

import xarray as xr
import matplotlib.pyplot as plt
from helpers.computational_tools import *


from helpers.collection_of_experiments import CollectionOfExperiments
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ds = CollectionOfExperiments.init_folder('/glade/derecho/scratch/pavelp/archive/', additional_subfolder='ocn/hist', Averaging_time=slice('0003','0005'))
exps = ['no-GM', 'GM', 'bANN', 'bANN-2']
# Out:
# bANN-8
# bANN
# bANN-2
# no-GM
# GM
# bANN-4
# /glade/derecho/scratch/pavelp/archive/bANN-8/ocn/hist
# /glade/derecho/scratch/pavelp/archive/bANN/ocn/hist
# /glade/derecho/scratch/pavelp/archive/bANN-2/ocn/hist
# /glade/derecho/scratch/pavelp/archive/no-GM/ocn/hist
# /glade/derecho/scratch/pavelp/archive/GM/ocn/hist
# /glade/derecho/scratch/pavelp/archive/bANN-4/ocn/hist

# %%
ds.exps
# Out:
# ['bANN-8', 'bANN', 'bANN-2', 'no-GM', 'GM', 'bANN-4']

# %%
ds_series = CollectionOfExperiments.init_folder('/glade/derecho/scratch/pavelp/', additional_subfolder='run')
# Out:
# GM
# bANN
# bANN-4
# no-GM
# bANN-2
# bANN-8
# /glade/derecho/scratch/pavelp/GM/run
# /glade/derecho/scratch/pavelp/bANN/run
# /glade/derecho/scratch/pavelp/bANN-4/run
# /glade/derecho/scratch/pavelp/no-GM/run
# /glade/derecho/scratch/pavelp/bANN-2/run
# /glade/derecho/scratch/pavelp/bANN-8/run

# %%
exps = ['no-GM', 'GM', 'bANN', 'bANN-2']

# %%
ds_series.plot_series(exps)

# %% [markdown]
# # T

# %%
ds.plot_temp(['no-GM', 'GM', 'bANN', 'bANN-2'], plot_type='response')
# Out:
# regridded

# %%
ds.plot_temp(['no-GM', 'GM', 'bANN', 'bANN-2'], plot_type='response', zl=11)

# %%
ds.plot_temp(['no-GM', 'GM', 'bANN', 'bANN-2'], plot_type='response', zl=20)

# %%
ds.plot_temp(['no-GM', 'GM', 'bANN', 'bANN-2'], plot_type='response', select=select_NA_large)

# %%
ds.plot_temp(['no-GM', 'GM', 'bANN', 'bANN-2'], plot_type='response', select=select_Pacific, projection='3D')

# %% [markdown]
# # S

# %%
ds.plot_so(['no-GM', 'GM', 'bANN', 'bANN-2'], plot_type='response', zl=0)

# %%
ds.plot_so(['no-GM', 'GM', 'bANN', 'bANN-2'], plot_type='response', zl=11)

# %%
ds.plot_so(['no-GM', 'GM', 'bANN', 'bANN-2'], plot_type='response', zl=0, select=select_NA_large)

# %%
ds.plot_so(['no-GM', 'GM', 'bANN', 'bANN-2'], plot_type='response', zl=0, select=select_Pacific, projection='3D')

# %% [markdown]
# # MLD

# %%
ds.plot_MLD_summer(exps, plot_type='response', projection='2D')

# %%
ds.plot_MLD_winter(exps, plot_type='response', projection='2D')

# %% [markdown]
# # SSH STD

# %%
ds.plot_ssh_std(exps, plot_type='response')

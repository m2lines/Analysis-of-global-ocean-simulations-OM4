# %%
import sys
sys.path.append('../')
# %load_ext autoreload
# %autoreload 3

import xarray as xr
import matplotlib.pyplot as plt
from helpers.computational_tools import *


from helpers.collection_of_experiments import CollectionOfExperiments

# %%
ds = CollectionOfExperiments.init_folder('/glade/derecho/scratch/pavelp/archive/', additional_subfolder='ocn/hist', Averaging_time=slice('0003','0005'))
# Out:
# bANN-8
# eANN_upd_code_boundary_smag
# bANN
# eANN_upd_code_boundary_2.5
# eANN_upd_code_boundary_1.5
# eANN_upd_code_boundary
# bANN-2
# eANN_upd_code_boundary_2.0
# eANN_upd_code_boundary_smag_MEKE_off
# no-GM
# GM
# bANN-4
# /glade/derecho/scratch/pavelp/archive/bANN-8/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_smag/ocn/hist
# /glade/derecho/scratch/pavelp/archive/bANN/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_2.5/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_1.5/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary/ocn/hist
# /glade/derecho/scratch/pavelp/archive/bANN-2/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_2.0/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_smag_MEKE_off/ocn/hist
# /glade/derecho/scratch/pavelp/archive/no-GM/ocn/hist
# /glade/derecho/scratch/pavelp/archive/GM/ocn/hist
# ...

# %%
ds.exps
# Out:
# ['bANN-8',
#  'eANN_upd_code_boundary_smag',
#  'bANN',
#  'eANN_upd_code_boundary_2.5',
#  'eANN_upd_code_boundary_1.5',
#  'eANN_upd_code_boundary',
#  'bANN-2',
#  'eANN_upd_code_boundary_2.0',
#  'eANN_upd_code_boundary_smag_MEKE_off',
#  'no-GM',
#  'GM',
#  'bANN-4']

# %%
ds_series = CollectionOfExperiments.init_folder('/glade/derecho/scratch/pavelp/', additional_subfolder='run')
# Out:
# GM
# bANN
# eANN_upd_code_boundary
# eANN_upd_code
# eANN_upd_code_boundary_2.5
# bANN-4
# eANN_upd_code_boundary_3.0
# no-GM
# bANN-2
# eANN_upd_code_boundary_4.0
# eANN_upd_code_boundary_smag
# bANN-8
# eANN_upd_code_boundary_8.0
# eANN_upd_code_boundary_1.5
# eANN_upd_code_boundary_2.0
# eANN
# eANN_upd_code_boundary_smag_MEKE_off
# /glade/derecho/scratch/pavelp/GM/run
# /glade/derecho/scratch/pavelp/bANN/run
# /glade/derecho/scratch/pavelp/eANN_upd_code_boundary/run
# /glade/derecho/scratch/pavelp/eANN_upd_code/run
# /glade/derecho/scratch/pavelp/eANN_upd_code_boundary_2.5/run
# /glade/derecho/scratch/pavelp/bANN-4/run
# /glade/derecho/scratch/pavelp/eANN_upd_code_boundary_3.0/run
# /glade/derecho/scratch/pavelp/no-GM/run
# /glade/derecho/scratch/pavelp/bANN-2/run
# /glade/derecho/scratch/pavelp/eANN_upd_code_boundary_4.0/run
# /glade/derecho/scratch/pavelp/eANN_upd_code_boundary_smag/run
# /glade/derecho/scratch/pavelp/bANN-8/run
# ...

# %%
exps = ['no-GM', 'eANN_upd_code_boundary', 'eANN_upd_code_boundary_1.5', 'eANN_upd_code_boundary_2.0', 'eANN_upd_code_boundary_2.5', 'eANN_upd_code_boundary_smag', 'eANN_upd_code_boundary_smag_MEKE_off']

# %%
ds_series.plot_series(exps)

# %% [markdown]
# # T

# %%
ds = CollectionOfExperiments.init_folder('/glade/derecho/scratch/pavelp/archive/', additional_subfolder='ocn/hist', Averaging_time=slice('0003','0005'))
# Out:
# bANN-8
# eANN_upd_code_boundary_smag
# bANN
# eANN_upd_code_boundary_2.5
# eANN_upd_code_boundary_1.5
# eANN_upd_code_boundary
# bANN-2
# eANN_upd_code_boundary_2.0
# eANN_upd_code_boundary_smag_MEKE_off
# no-GM
# GM
# bANN-4
# /glade/derecho/scratch/pavelp/archive/bANN-8/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_smag/ocn/hist
# /glade/derecho/scratch/pavelp/archive/bANN/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_2.5/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_1.5/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary/ocn/hist
# /glade/derecho/scratch/pavelp/archive/bANN-2/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_2.0/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_smag_MEKE_off/ocn/hist
# /glade/derecho/scratch/pavelp/archive/no-GM/ocn/hist
# /glade/derecho/scratch/pavelp/archive/GM/ocn/hist
# ...

# %%
ds.plot_temp(['no-GM', 'eANN_upd_code_boundary', 'eANN_upd_code_boundary_1.5', 'eANN_upd_code_boundary_2.0', 'eANN_upd_code_boundary_2.5', 'eANN_upd_code_boundary_smag',  'eANN_upd_code_boundary_smag_MEKE_off'], plot_type='response')
# Out:
# regridded

# %% [markdown]
# # SSH STD

# %%
ds = CollectionOfExperiments.init_folder('/glade/derecho/scratch/pavelp/archive/', additional_subfolder='ocn/hist', Averaging_time=slice('0003','0005'))
# Out:
# bANN-8
# eANN_upd_code_boundary_smag
# bANN
# eANN_upd_code_boundary_2.5
# eANN_upd_code_boundary_1.5
# eANN_upd_code_boundary
# bANN-2
# eANN_upd_code_boundary_2.0
# eANN_upd_code_boundary_smag_MEKE_off
# no-GM
# GM
# bANN-4
# /glade/derecho/scratch/pavelp/archive/bANN-8/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_smag/ocn/hist
# /glade/derecho/scratch/pavelp/archive/bANN/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_2.5/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_1.5/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary/ocn/hist
# /glade/derecho/scratch/pavelp/archive/bANN-2/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_2.0/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_smag_MEKE_off/ocn/hist
# /glade/derecho/scratch/pavelp/archive/no-GM/ocn/hist
# /glade/derecho/scratch/pavelp/archive/GM/ocn/hist
# ...

# %%
ds.plot_ssh_std(['no-GM', 'eANN_upd_code_boundary', 'eANN_upd_code_boundary_1.5', 'eANN_upd_code_boundary_2.0', 'eANN_upd_code_boundary_2.5', 'eANN_upd_code_boundary_smag', 'obs'], select=select_NA_large, projection='3D')

# %%
 ds.plot_ssh_std(['no-GM', 'eANN_upd_code_boundary', 'eANN_upd_code_boundary_1.5', 'eANN_upd_code_boundary_2.0', 'eANN_upd_code_boundary_2.5', 'eANN_upd_code_boundary_smag', 'obs'], select=select_NA_large, projection='3D', plot_type='response')

# %%
ds.plot_ssh_std(['no-GM', 'eANN_upd_code_boundary', 'eANN_upd_code_boundary_1.5', 'eANN_upd_code_boundary_2.0', 'eANN_upd_code_boundary_2.5', 'eANN_upd_code_boundary_smag', 'obs'], select=select_Pacific, projection='3D')

# %%
ds.plot_ssh_std(['no-GM', 'eANN_upd_code_boundary', 'eANN_upd_code_boundary_1.5', 'eANN_upd_code_boundary_2.0', 'eANN_upd_code_boundary_2.5', 'eANN_upd_code_boundary_smag', 'obs'], select=select_globe, projection='2D')

# %%
ds = CollectionOfExperiments.init_folder('/glade/derecho/scratch/pavelp/archive/', additional_subfolder='ocn/hist', Averaging_time=slice('0003','0005'))
# Out:
# bANN-8
# eANN_upd_code_boundary_smag
# bANN
# eANN_upd_code_boundary_2.5
# eANN_upd_code_boundary_1.5
# eANN_upd_code_boundary
# bANN-2
# eANN_upd_code_boundary_2.0
# eANN_upd_code_boundary_smag_MEKE_off
# no-GM
# GM
# bANN-4
# /glade/derecho/scratch/pavelp/archive/bANN-8/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_smag/ocn/hist
# /glade/derecho/scratch/pavelp/archive/bANN/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_2.5/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_1.5/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary/ocn/hist
# /glade/derecho/scratch/pavelp/archive/bANN-2/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_2.0/ocn/hist
# /glade/derecho/scratch/pavelp/archive/eANN_upd_code_boundary_smag_MEKE_off/ocn/hist
# /glade/derecho/scratch/pavelp/archive/no-GM/ocn/hist
# /glade/derecho/scratch/pavelp/archive/GM/ocn/hist
# ...

# %%
ds.plot_ssh(['no-GM', 'eANN_upd_code_boundary', 'eANN_upd_code_boundary_1.5', 'eANN_upd_code_boundary_2.0', 'eANN_upd_code_boundary_2.5', 'eANN_upd_code_boundary_smag'], select=select_NA_large, projection='2D')

# %%
ds.plot_ssh(['no-GM', 'eANN_upd_code_boundary', 'eANN_upd_code_boundary_1.5', 'eANN_upd_code_boundary_2.0', 'eANN_upd_code_boundary_2.5', 'eANN_upd_code_boundary_smag'], 
            select=select_Pacific, projection='3D')

# %%
ds.plot_geovel(['no-GM', 'eANN_upd_code_boundary', 'eANN_upd_code_boundary_1.5', 'eANN_upd_code_boundary_2.0', 'eANN_upd_code_boundary_2.5', 'eANN_upd_code_boundary_smag', 'obs'], select=select_NA_large, projection='2D')

# %%
ds.plot_geovel(['no-GM', 'eANN_upd_code_boundary', 'eANN_upd_code_boundary_1.5', 'eANN_upd_code_boundary_2.0', 'eANN_upd_code_boundary_2.5', 'eANN_upd_code_boundary_smag', 'obs'], select=select_Pacific, projection='3D')

# %%
import sys
sys.path.append('../')
# %load_ext autoreload
# %autoreload 3

import xarray as xr

from helpers.collection_of_experiments import CollectionOfExperiments
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ds = CollectionOfExperiments.init_folder('/scratch/pp2681/mom6/OM4_SIS2')

# %%
ds.exps
# Out:
# ['unparameterized-0.09',
#  'unparameterized',
#  'ZB20-Reynolds',
#  'ZB20-Klower',
#  'ANN-5x5-Klower',
#  'vert-diff',
#  'JHAH15',
#  'unparameterized-OM5',
#  'ANN-3x3-EXP2',
#  'ANN-redline',
#  'ANN-greenline',
#  'GM',
#  'ANN-1x1',
#  'DMM-R',
#  'unparameterized-0.03']

# %%
ds.plot_series(['unparameterized', 'ZB20-Klower', 'ZB20-Reynolds'])
plt.suptitle('Filters in ZB20')
# Out:
# Text(0.5, 0.98, 'Filters in ZB20')

# %%
ds.plot_series(['unparameterized', 'ANN-greenline', 'ANN-3x3-EXP2'], colors=['tab:gray', 'tab:green', 'g'])
plt.suptitle('Reproducibility in \n3x3 20 neuron model', y=1.05)
# Out:
# Text(0.5, 1.05, 'Reproducibility in \n3x3 20 neuron model')

# %%
ds.plot_series(['unparameterized', 'ANN-greenline', 'ANN-1x1', 'ANN-5x5-Klower'], colors=['tab:gray', 'tab:green', 'tab:orange', 'tab:cyan', violet])
plt.suptitle('Effect of the stencil size', y=1.01)
# Out:
# Text(0.5, 1.01, 'Effect of the stencil size')

# %%
import sys
sys.path.append('../')
# %load_ext autoreload
# %autoreload 3

import xarray as xr
import matplotlib.pyplot as plt

from helpers.collection_of_experiments import CollectionOfExperiments
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ds = CollectionOfExperiments.init_folder('/scratch/pp2681/mom6/OM4_SIS2')

# %%
ds.exps
# Out:
# ['unparameterized-0.09',
#  'unparameterized',
#  'ZB20-Reynolds',
#  'ZB20-Klower',
#  'ANN-5x5-Klower',
#  'ANN-3x3-32-32',
#  'vert-diff',
#  'JHAH15',
#  'unparameterized-OM5',
#  'ANN-3x3-EXP2',
#  'ANN-redline',
#  'ANN-greenline',
#  'GM',
#  'ANN-1x1',
#  'DMM-R',
#  'unparameterized-0.03']

# %%
ds.plot_series(['unparameterized', 'ZB20-Klower', 'ZB20-Reynolds'])
plt.suptitle('Filters in ZB20')
# Out:
# Text(0.5, 0.98, 'Filters in ZB20')

# %%
# %time ds.plot_temp(['ANN-redline', 'GM', 'ANN-greenline'], zl=0)
# Out:
# CPU times: user 226 ms, sys: 38.7 ms, total: 264 ms
# Wall time: 267 ms

# %%
# %time ds.plot_temp(['ANN-redline', 'GM', 'ANN-greenline'], zl=0, select=select_Kuroshio_Juricke)
# Out:
# CPU times: user 264 ms, sys: 60.8 ms, total: 325 ms
# Wall time: 329 ms

# %%
# %time ds.plot_temp(['unparameterized', 'ZB20-Klower', 'ZB20-Reynolds', 'ANN-greenline'], zl=0, select=select_Gulf_Juricke, \
                   plot_type = 'bias')
# Out:
# CPU times: user 667 ms, sys: 95.4 ms, total: 763 ms
# Wall time: 794 ms

# %%
# %time ds.plot_temp(['unparameterized', 'ZB20-Klower', 'ZB20-Reynolds', 'ANN-greenline'], zl=0, select=select_Gulf_Juricke, \
                   plot_type = 'response')
# Out:
# CPU times: user 347 ms, sys: 77.7 ms, total: 425 ms
# Wall time: 428 ms

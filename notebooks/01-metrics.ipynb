# %%
import sys
sys.path.append('../')
# %load_ext autoreload
# %autoreload 3

import xarray as xr
import matplotlib.pyplot as plt

from helpers.collection_of_experiments import CollectionOfExperiments
from helpers.computational_tools import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ds = CollectionOfExperiments.init_folder('/scratch/pp2681/mom6/OM4_SIS2')

# %%
ds.exps
# Out:
# ['unparameterized-0.09',
#  'unparameterized',
#  'ZB20-Reynolds',
#  'ZB20-Klower',
#  'ANN-5x5-Klower',
#  'ANN-3x3-32-32',
#  'vert-diff',
#  'JHAH15',
#  'unparameterized-OM5',
#  'ANN-3x3-EXP2',
#  'ANN-redline',
#  'ANN-greenline',
#  'GM',
#  'ANN-1x1',
#  'DMM-R',
#  'unparameterized-0.03']

# %%
ds.plot_series(['unparameterized', 'ZB20-Klower', 'ZB20-Reynolds', 'ANN-greenline'])
plt.suptitle('Filters in ZB20')
# Out:
# Text(0.5, 0.98, 'Filters in ZB20')

# %%
# %time ds.plot_temp(['ANN-redline', 'GM', 'ANN-greenline'], zl=0, projection='3D')
# Out:
# CPU times: user 308 ms, sys: 95.4 ms, total: 404 ms
# Wall time: 607 ms

# %%
# %time ds.plot_temp(['ANN-redline', 'GM', 'ANN-greenline'], zl=0, select=select_Kuroshio)
# Out:
# CPU times: user 289 ms, sys: 91.2 ms, total: 380 ms
# Wall time: 356 ms

# %%
# %time ds.plot_temp(['unparameterized', 'ZB20-Klower', 'ZB20-Reynolds', 'ANN-greenline'], zl=0, select=select_Gulf, \
                   plot_type = 'response')
# Out:
# CPU times: user 861 ms, sys: 255 ms, total: 1.12 s
# Wall time: 1.24 s

# %%
# %time ds.plot_temp(['unparameterized', 'ZB20-Klower', 'ZB20-Reynolds', 'ANN-greenline'], zl=6, select=select_Gulf, \
                   plot_type = 'response')
# Out:
# CPU times: user 872 ms, sys: 246 ms, total: 1.12 s
# Wall time: 1.16 s

# %%
# %time ds.plot_temp_section(['unparameterized', 'ZB20-Klower', 'ZB20-Reynolds', 'ANN-greenline'], select=select_Drake, \
                   plot_type = 'response')
# Out:
# CPU times: user 1.48 s, sys: 336 ms, total: 1.82 s
# Wall time: 1.91 s

# %%
# %time ds.plot_MLD_summer(['unparameterized', 'ZB20-Klower', 'ZB20-Reynolds', 'ANN-greenline'], select=select_globe, \
                   plot_type = 'bias', projection='3D')
# Out:
# CPU times: user 233 ms, sys: 8.88 ms, total: 242 ms
# Wall time: 247 ms

# %%
# %time ds.plot_MLD_winter(['unparameterized', 'ZB20-Klower', 'ZB20-Reynolds', 'ANN-greenline'], select=select_globe, \
                   plot_type = 'bias', projection='3D')
# Out:
# CPU times: user 5.65 s, sys: 966 ms, total: 6.62 s
# Wall time: 7.47 s

# %%
# %time ds.plot_ssh_std(['unparameterized', 'ZB20-Klower', 'ZB20-Reynolds', 'ANN-greenline'], select=select_globe, \
                   plot_type = 'default', projection='3D')
# Out:
# CPU times: user 225 ms, sys: 12 ms, total: 237 ms
# Wall time: 319 ms
